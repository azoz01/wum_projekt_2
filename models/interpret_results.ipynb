# %%
# %load_ext lab_black

# %%
import os
os.chdir("..")

# %%
import pandas as pd

results_df = pd.read_pickle("models/results/results.pkl")
results_df
# Out:
#                                     value                                     \
# metric                               WCSS               Silhouette
# type                                train          test      train      test
# encoding       model
# Tf-idf         KMeans        23684.209513  10145.843607   0.006331  0.006253
#                Random model  24054.285517  10304.296932  -0.000153 -0.000207
# Word embedding KMeans        28001.487356  11785.237404   0.129076  0.127968
#                Random model  49428.750954  20929.603547  -0.003268 -0.005502
#
#                                                               \
# metric                      Min intercluster dist.
# type                                         train      test
# encoding       model
# Tf-idf         KMeans                        error     error
#                Random model                  error     error
# Word embedding KMeans                     0.105479  0.105479
# ...
